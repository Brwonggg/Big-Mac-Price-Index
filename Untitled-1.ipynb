# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
WEBSITE= "https://statbase.org/data/sgp-bigmac-price/"

response = requests.get(WEBSITE)
soup = BeautifulSoup(response.text, 'html.parser')
soup.find_all("div",class_="iyt_value")
# with open("bigmac.csv","w", encoding="utf-8") as f:
#     f.write(data.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 6
#       4 soup = BeautifulSoup(response.text, 'html.parser')
#       5 data = soup.find_all("div",class_="ind_years_table table-protected")
# ----> 6 data.get_text()
#       7 # with open("bigmac.csv","w", encoding="utf-8") as f:
#       8 #     f.write(data.text)
#
# File ~/.local/lib/python3.12/site-packages/bs4/element.py:2885, in ResultSet.__getattr__(self, key)
#    2883 def __getattr__(self, key: str) -> None:
#    2884     """Raise a helpful exception to explain a common code fix."""
# -> 2885     raise AttributeError(
#    2886         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2887     )
#
# AttributeError: ResultSet object has no attribute "get_text". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
